# %%
# Initial imports
import os
import pandas as pd
import requests
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Reading the News API key enviroment variable
api_key = os.getenv("crypto_news_key")

# %%
print(f"API key:{type(api_key)}")
# Out:
# API key:<class 'str'>

# %%
#Retrieve the top most mentioned tickers. Use the &date= parameter to specify your desired date range.
top_mentioned_crypto_tickers = 'https://cryptonews-api.com/api/v1/top-mention?&date=last7days&token='+api_key

# %%
response_top_mentioned_crypto_tickers = requests.get(top_mentioned_crypto_tickers)

# %%
response_top_mentioned_crypto_tickers.json()
# Out:
# {'data': {'all': [{'total_mentions': 390,
#     'positive_mentions': 164,
#     'negative_mentions': 50,
#     'neutral_mentions': 176,
#     'ticker': 'BTC',
#     'name': 'Bitcoin',
#     'sentiment_score': 0.89},
#    {'total_mentions': 112,
#     'positive_mentions': 33,
#     'negative_mentions': 10,
#     'neutral_mentions': 69,
#     'ticker': 'ETH',
#     'name': 'Ethereum',
#     'sentiment_score': 0.924},
#    {'total_mentions': 76,
#     'positive_mentions': 8,
#     'negative_mentions': 21,
#     'neutral_mentions': 47,
#     'ticker': 'XRP',
#     'name': 'Ripple',
#     'sentiment_score': 0.362},
#    {'total_mentions': 29,
#     'positive_mentions': 11,
#     'negative_mentions': 2,
#     'neutral_mentions': 16,
#     'ticker': 'ADA',
#     'name': 'Cardano',
#     'sentiment_score': 1.017},
#    {'total_mentions': 27,
#     'positive_mentions': 9,
#     'negative_mentions': 1,
#     'neutral_mentions': 17,
#     'ticker': 'DOGE',
#     'name': 'Dogecoin',
#     'sentiment_score': 1.074},
#    {'total_mentions': 20,
#     'positive_mentions': 4,
#     'negative_mentions': 0,
#     'neutral_mentions': 16,
#     'ticker': 'BNB',
#     'name': 'Binance Coin',
#     'sentiment_score': 1.1},
#    {'total_mentions': 19,
#     'positive_mentions': 5,
#     'negative_mentions': 1,
#     'neutral_mentions': 13,
#     'ticker': 'DOT',
#     'name': 'Polkadot',
#     'sentiment_score': 1},
#    {'total_mentions': 18,
#     'positive_mentions': 2,
#     'negative_mentions': 1,
#     'neutral_mentions': 15,
#     'ticker': 'UNI',
#     'name': 'Uniswap',
#     'sentiment_score': 0.917},
#    {'total_mentions': 15,
#     'positive_mentions': 6,
#     'negative_mentions': 0,
#     'neutral_mentions': 9,
#     'ticker': 'SUSHI',
#     'name': 'SushiSwap',
#     'sentiment_score': 1.2},
#    {'total_mentions': 11,
#     'positive_mentions': 1,
#     'negative_mentions': 1,
#     'neutral_mentions': 9,
#     'ticker': 'LTC',
#     'name': 'Litecoin',
#     'sentiment_score': 0.818},
#    {'total_mentions': 10,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 9,
#     'ticker': 'BCH',
#     'name': 'Bitcoin Cash',
#     'sentiment_score': 1.05},
#    {'total_mentions': 10,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 9,
#     'ticker': 'TRX',
#     'name': 'TRON',
#     'sentiment_score': 1.05},
#    {'total_mentions': 10,
#     'positive_mentions': 0,
#     'negative_mentions': 9,
#     'neutral_mentions': 1,
#     'ticker': 'CAKE',
#     'name': 'PancakeSwap',
#     'sentiment_score': -1.25},
#    {'total_mentions': 10,
#     'positive_mentions': 5,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'MATIC',
#     'name': 'Polygon',
#     'sentiment_score': 1.25},
#    {'total_mentions': 8,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 8,
#     'ticker': 'XMR',
#     'name': 'Monero',
#     'sentiment_score': 1},
#    {'total_mentions': 8,
#     'positive_mentions': 2,
#     'negative_mentions': 0,
#     'neutral_mentions': 6,
#     'ticker': 'LINK',
#     'name': 'Chainlink',
#     'sentiment_score': 1.125},
#    {'total_mentions': 8,
#     'positive_mentions': 0,
#     'negative_mentions': 7,
#     'neutral_mentions': 1,
#     'ticker': 'CREAM',
#     'name': 'Cream Finance',
#     'sentiment_score': -1.188},
#    {'total_mentions': 8,
#     'positive_mentions': 2,
#     'negative_mentions': 0,
#     'neutral_mentions': 6,
#     'ticker': 'MIOTA',
#     'name': 'IOTA',
#     'sentiment_score': 1.125},
#    {'total_mentions': 7,
#     'positive_mentions': 3,
#     'negative_mentions': 1,
#     'neutral_mentions': 3,
#     'ticker': 'XEM',
#     'name': 'NEM',
#     'sentiment_score': 0.857},
#    {'total_mentions': 7,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 6,
#     'ticker': 'XTZ',
#     'name': 'Tezos',
#     'sentiment_score': 1.071},
#    {'total_mentions': 7,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 6,
#     'ticker': 'VET',
#     'name': 'VeChain',
#     'sentiment_score': 1.071},
#    {'total_mentions': 7,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 7,
#     'ticker': 'EOS',
#     'name': 'EOS',
#     'sentiment_score': 1},
#    {'total_mentions': 6,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 6,
#     'ticker': 'CRO',
#     'name': 'Crypto.com Coin',
#     'sentiment_score': 1},
#    {'total_mentions': 6,
#     'positive_mentions': 6,
#     'negative_mentions': 0,
#     'neutral_mentions': 0,
#     'ticker': 'AVAX',
#     'name': 'Avalanche',
#     'sentiment_score': 1.5},
#    {'total_mentions': 6,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'DASH',
#     'name': 'Dash',
#     'sentiment_score': 1.083},
#    {'total_mentions': 6,
#     'positive_mentions': 3,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'ENJ',
#     'name': 'Enjin Coin',
#     'sentiment_score': 1.25},
#    {'total_mentions': 6,
#     'positive_mentions': 3,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'AAVE',
#     'name': 'Aave',
#     'sentiment_score': 1.25},
#    {'total_mentions': 5,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'BAT',
#     'name': 'Basic Attention Token',
#     'sentiment_score': 1},
#    {'total_mentions': 5,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'COMP',
#     'name': 'Compound',
#     'sentiment_score': 1},
#    {'total_mentions': 5,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'ATOM',
#     'name': 'Cosmos',
#     'sentiment_score': 1},
#    {'total_mentions': 5,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 5,
#     'ticker': 'BSV',
#     'name': 'Bitcoin SV',
#     'sentiment_score': 1},
#    {'total_mentions': 5,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 4,
#     'ticker': 'FTT',
#     'name': 'FTX Token',
#     'sentiment_score': 1.1},
#    {'total_mentions': 4,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 4,
#     'ticker': 'ZEC',
#     'name': 'Zcash',
#     'sentiment_score': 1},
#    {'total_mentions': 4,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'ALGO',
#     'name': 'Algorand',
#     'sentiment_score': 1.125},
#    {'total_mentions': 4,
#     'positive_mentions': 2,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'USDT',
#     'name': 'Tether',
#     'sentiment_score': 1.25},
#    {'total_mentions': 4,
#     'positive_mentions': 3,
#     'negative_mentions': 0,
#     'neutral_mentions': 1,
#     'ticker': 'CHZ',
#     'name': 'Chiliz',
#     'sentiment_score': 1.375},
#    {'total_mentions': 4,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 4,
#     'ticker': 'DCR',
#     'name': 'Decred',
#     'sentiment_score': 1},
#    {'total_mentions': 3,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'SOL',
#     'name': 'Solana',
#     'sentiment_score': 1},
#    {'total_mentions': 3,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'YFI',
#     'name': 'yearn.finance',
#     'sentiment_score': 1.167},
#    {'total_mentions': 3,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'XLM',
#     'name': 'Stellar',
#     'sentiment_score': 1},
#    {'total_mentions': 3,
#     'positive_mentions': 1,
#     'negative_mentions': 1,
#     'neutral_mentions': 1,
#     'ticker': 'HBAR',
#     'name': 'Hedera Hashgraph',
#     'sentiment_score': 0.333},
#    {'total_mentions': 3,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'ZIL',
#     'name': 'Zilliqa',
#     'sentiment_score': 1.167},
#    {'total_mentions': 3,
#     'positive_mentions': 0,
#     'negative_mentions': 1,
#     'neutral_mentions': 2,
#     'ticker': 'SNX',
#     'name': 'Synthetix',
#     'sentiment_score': 0.167},
#    {'total_mentions': 3,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 3,
#     'ticker': 'WAVES',
#     'name': 'Waves',
#     'sentiment_score': 1},
#    {'total_mentions': 2,
#     'positive_mentions': 2,
#     'negative_mentions': 0,
#     'neutral_mentions': 0,
#     'ticker': 'MANA',
#     'name': 'Decentraland',
#     'sentiment_score': 1.5},
#    {'total_mentions': 2,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 1,
#     'ticker': 'SKL',
#     'name': 'SKALE Network',
#     'sentiment_score': 1.25},
#    {'total_mentions': 2,
#     'positive_mentions': 1,
#     'negative_mentions': 0,
#     'neutral_mentions': 1,
#     'ticker': 'IOTX',
#     'name': 'IoTeX',
#     'sentiment_score': 1.25},
#    {'total_mentions': 2,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'PAID',
#     'name': 'PAID Network',
#     'sentiment_score': 1},
#    {'total_mentions': 2,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'CRV',
#     'name': 'Curve DAO Token',
#     'sentiment_score': 1},
#    {'total_mentions': 2,
#     'positive_mentions': 0,
#     'negative_mentions': 0,
#     'neutral_mentions': 2,
#     'ticker': 'NEO',
#     'name': 'Neo',
#     'sentiment_score': 1}]}}

# %%
top_mentioned_crypto_raw = response_top_mentioned_crypto_tickers.json()

# %%
top_mentioned_crypto_df = pd.DataFrame(data = top_mentioned_crypto_raw['data'])

# %%
top_mentioned_crypto_df
# Out:
#                                                   all
# 0   {'total_mentions': 390, 'positive_mentions': 1...
# 1   {'total_mentions': 112, 'positive_mentions': 3...
# 2   {'total_mentions': 76, 'positive_mentions': 8,...
# 3   {'total_mentions': 29, 'positive_mentions': 11...
# 4   {'total_mentions': 27, 'positive_mentions': 9,...
# 5   {'total_mentions': 20, 'positive_mentions': 4,...
# 6   {'total_mentions': 19, 'positive_mentions': 5,...
# 7   {'total_mentions': 18, 'positive_mentions': 2,...
# 8   {'total_mentions': 15, 'positive_mentions': 6,...
# 9   {'total_mentions': 11, 'positive_mentions': 1,...
# 10  {'total_mentions': 10, 'positive_mentions': 1,...
# 11  {'total_mentions': 10, 'positive_mentions': 1,...
# 12  {'total_mentions': 10, 'positive_mentions': 0,...
# 13  {'total_mentions': 10, 'positive_mentions': 5,...
# 14  {'total_mentions': 8, 'positive_mentions': 0, ...
# 15  {'total_mentions': 8, 'positive_mentions': 2, ...
# 16  {'total_mentions': 8, 'positive_mentions': 0, ...
# 17  {'total_mentions': 8, 'positive_mentions': 2, ...
# 18  {'total_mentions': 7, 'positive_mentions': 3, ...
# 19  {'total_mentions': 7, 'positive_mentions': 1, ...
# 20  {'total_mentions': 7, 'positive_mentions': 1, ...
# 21  {'total_mentions': 7, 'positive_mentions': 0, ...
# 22  {'total_mentions': 6, 'positive_mentions': 0, ...
# 23  {'total_mentions': 6, 'positive_mentions': 6, ...
# 24  {'total_mentions': 6, 'positive_mentions': 1, ...
# 25  {'total_mentions': 6, 'positive_mentions': 3, ...
# 26  {'total_mentions': 6, 'positive_mentions': 3, ...
# 27  {'total_mentions': 5, 'positive_mentions': 0, ...
# 28  {'total_mentions': 5, 'positive_mentions': 0, ...
# 29  {'total_mentions': 5, 'positive_mentions': 0, ...
# 30  {'total_mentions': 5, 'positive_mentions': 0, ...
# 31  {'total_mentions': 5, 'positive_mentions': 1, ...
# 32  {'total_mentions': 4, 'positive_mentions': 0, ...
# 33  {'total_mentions': 4, 'positive_mentions': 1, ...
# 34  {'total_mentions': 4, 'positive_mentions': 2, ...
# 35  {'total_mentions': 4, 'positive_mentions': 3, ...
# 36  {'total_mentions': 4, 'positive_mentions': 0, ...
# 37  {'total_mentions': 3, 'positive_mentions': 0, ...
# 38  {'total_mentions': 3, 'positive_mentions': 1, ...
# 39  {'total_mentions': 3, 'positive_mentions': 0, ...
# 40  {'total_mentions': 3, 'positive_mentions': 1, ...
# 41  {'total_mentions': 3, 'positive_mentions': 1, ...
# 42  {'total_mentions': 3, 'positive_mentions': 0, ...
# 43  {'total_mentions': 3, 'positive_mentions': 0, ...
# 44  {'total_mentions': 2, 'positive_mentions': 2, ...
# 45  {'total_mentions': 2, 'positive_mentions': 1, ...
# 46  {'total_mentions': 2, 'positive_mentions': 1, ...
# 47  {'total_mentions': 2, 'positive_mentions': 0, ...
# 48  {'total_mentions': 2, 'positive_mentions': 0, ...
# 49  {'total_mentions': 2, 'positive_mentions': 0, ...
